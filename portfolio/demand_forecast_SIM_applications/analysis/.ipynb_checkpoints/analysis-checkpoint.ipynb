# %%
# analysis.ipynb
import pandas as pd
from pathlib import Path
import datetime as dt
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression
from src.load_data import load_daily_data

import os
from pathlib import Path
print("cwd:", os.getcwd())
print("exists src?:", (Path(os.getcwd()) / "src").exists())
print("parent has src?:", (Path(os.getcwd()).parent / "src").exists())
# === CSV読み込み ===
DATA_PATH = Path("../data/csv/sim_applications.csv")
df = pd.read_csv(DATA_PATH)
df["date"] = pd.to_datetime(df["date"])


# === 月ごとに集計 ===
df_monthly = (
    df
    .set_index("date")
    .resample("M")
    .sum()
)

# resample と group_by の違いの確認
# df_sim_appliccations_monthly_v2 = (
#     df_sim_appliccations_daily
#     .set_index("date")
#     .groupby("month")["applications"]
#     .sum()
#     .reset_index()
# )

# print(df_sim_appliccations_monthly_v2)

# === 3ヶ月の移動平均を算出,過去3日ヶ月分のデータを追加 ===
df_monthly["ma3"] = (
    df_monthly["applications"]
    .rolling(3)
    .mean()
    )

for n in range(1, 4):
    df_monthly[f"prev_{n}"] = (
        df_monthly["applications"]
        .shift(n)
        )

print(df_monthly)

# === 月次合計と3ヶ月平均のグラフ作成 ===
graph_path = Path("images/analysis.png")
fig = plt.figure()

# グラフ描画処理
sim_applications = df_monthly["applications"]
monthly_2024 = df_monthly.index

plt.plot(monthly_2024, sim_applications)
plt.plot(df_monthly["ma3"])
plt.xlabel("monthly")
plt.ylabel("SIM_applications")
plt.title("2024 SIM applications")
plt.savefig(graph_path)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 7
#       5 import matplotlib.pyplot as plt
#       6 from sklearn.linear_model import LinearRegression
# ----> 7 from src.load_data import load_daily_data
#       9 import os
#      10 from pathlib import Path
#
# ModuleNotFoundError: No module named 'src'
